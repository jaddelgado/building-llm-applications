# %%
# Cheaper alternative: Groq
from groq import Groq

client = Groq(api_key="your-groq-key")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[15], line 2
#
#       1 # Cheaper alternative: Groq
#
# ----> 2 from groq import Groq
#
#       4 client = Groq(api_key="your-groq-key")
#
#
#
# ModuleNotFoundError: No module named 'groq'

# %%
from groq import Groq

client = Groq(api_key="your-groq-key")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[6], line 1
#
# ----> 1 from groq import Groq
#
#       3 client = Groq(api_key="your-groq-key")
#
#
#
# ModuleNotFoundError: No module named 'groq'
